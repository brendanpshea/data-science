# %% [markdown]
# <a href="https://colab.research.google.com/github/brendanpshea/data-science/blob/main/DataScience_08_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Analysis Types and Techniques
# ### Brendan Shea, PhD
# In today's data-driven world, businesses are constantly seeking ways to leverage their vast troves of information to gain a competitive edge. **Data analysis** has become an indispensable tool for decision-makers across industries, allowing them to uncover hidden patterns, predict future trends, and optimize their operations. But with the sheer volume and variety of data available, how can we effectively transform raw information into actionable insights?
#
# This chapter delves into the fascinating world of **data analysis types and techniques**, providing you with a comprehensive toolkit to tackle real-world business challenges. We'll explore various analytical approaches, from trend and performance analysis to exploratory data analysis and link analysis, each offering unique perspectives on your data.
#
# Throughout this chapter, we'll use a practical scenario involving a fictional Minnesota-based gourmet burger chain to illustrate how these analytical techniques can be applied in a business context. You'll learn how to:
#
# - **Determine the most appropriate type of analysis** for a given business question
# - **Leverage SQL data warehouses** to store and retrieve relevant information
# - **Apply various analytical techniques** using pandas and SQLite
# - **Interpret results** and translate them into actionable recommendations
#
# By the end of this chapter, you'll have a solid understanding of when and how to apply different types of data analysis, empowering you to make data-driven decisions with confidence. So, let's fire up our analytical engines and embark on this exciting journey into the world of data analysis!
#
# ### Data Analysis Exercises
# I've included several data analysis exercises in this chapter. These are signficantly more involved than many of the exercises/problems you have seen so far. I'd encourage you to choose one and try to do it in depth (as opposed to doing several exercises incompletely). You can feel free to use AI tools (such as the Gemini built into colab), but I think you'll find that these require some actual human thought!

# %% [markdown]
# ## Brendan's Lecture

# %%
##Click here to launch my lecture
from IPython.display import YouTubeVideo
YouTubeVideo('AZ1tWZk1NCU', width=800, height=500)

# %% [markdown]
# ## Scenario: "Juicy Lucy's Gourmet Burger Emporium"
#
# Welcome to the world of "Juicy Lucy's Gourmet Burger Emporium," a quirky and beloved Minnesota-based fast-food chain that's taking the Midwest by storm. Founded by the eccentric entrepreneur Lucy Larson, this chain has gained a cult following for its outrageous burger creations and commitment to using only the finest local ingredients.
#
# Some of Juicy Lucy's claim to fame includes:
#
# 1. The "Minnesotan Madness": A cheese-stuffed burger topped with tater tot hotdish and a drizzle of grape jelly ketchup.
# 2. The "Lutefisk Surprise": A whitefish patty soaked in lye, topped with lingonberry sauce and crispy fried onions (surprisingly popular during the holiday season).
# 3. The "Paul Bunyan's Breakfast": A mammoth burger featuring a pancake bun, sausage patty, fried egg, and maple syrup aioli.
#
# With 25 locations across Minnesota and plans for rapid expansion, Juicy Lucy's is at a critical juncture. They've collected mountains of data from their point-of-sale systems, customer loyalty program, social media engagement, and even their quirky "Rate-Your-Burp" app. Now, they need your help to make sense of it all.
#
# As a data scientist hired by Juicy Lucy's, your mission is to help them answer pressing questions such as:
#
# 1. Which menu items are driving customer loyalty?
# 2. Is there a correlation between local temperature and sales of their "Snowstorm Sizzler" (a burger served on a bed of warm cheese sauce)?
# 3. How effective was their recent "Eat a 5-pound burger, get a free t-shirt" promotion?
# 4. Can they predict demand for their seasonal "State Fair on a Bun" burger (featuring mini corn dogs and cotton candy)?
#
# Throughout this chapter, we'll use Juicy Lucy's data to demonstrate various analysis techniques, helping this unique burger chain make data-driven decisions to fuel their cheesy, juicy empire. Get ready to sink your teeth into some meaty data challenges!

# %% [markdown]
# ## How Do We Choose the Right Analytical Approach?
#
# Before diving into specific analysis techniques, it's crucial to establish a systematic process for determining the most appropriate type of analysis for a given business problem. This process ensures that we're asking the right questions, using the correct data, and applying the most suitable analytical methods. Let's break down this process into three key steps:
#
# ### 1. Review and Refine Business Questions
#
# The first step in any data analysis project is to clearly define the business questions you're trying to answer. This involves:
#
# - Work closely with **stakeholders** like business leaders, managers, and other relevant parties to understand their needs and objectives.
# - Clarify ambiguities by ensuring that all terms are well-defined and that the sc Identify which questions are most critical to the business's success.
# - Translate business questions into specific, measurable analytical questions.
#
# For example, at Juicy Lucy's, a vague question like "How can we improve our menu?" might be refined to "Which menu items are associated with the highest customer retention rates over a 6-month period?"
#
# ### 2. Determine Data Sources
#
# Once you've defined your questions, the next step is to identify the data sources that will help you answer them. This involves:
#
# - Conducting an inventory of all potential data sources within the organization, including **transactional databases**, **customer relationship management (CRM) systems**, and **external data sources**.
# - Assess data quality to Evaluate the completeness, accuracy, and timeliness of each data source.
# - Identify data gaps, and determine if additional data collection is necessary to answer your questions.
# - Assess the feasibility of combining data from multiple sources.
#
# This is an excellent time to revisit concepts like **data lakes**, which can store vast amounts of raw data in its native format, and **data mining/cleaning techniques**, which will be crucial for preparing your data for analysis. We've covered these in earlier chapters.
#
# In the case of Juicy Lucy's, you might need to combine data from their point-of-sale systems, customer loyalty program, and even their "Rate-Your-Burp" app to get a comprehensive view of customer behavior and preferences.
#
# ### 3. Scoping and Gap Analysis
#
# The final step in this process is to scope your analysis and identify any gaps between what you want to know and what your available data can tell you. This includes:
#
# - Defining the **analysis scope**. This means clearly outlining what will and won't be included in your analysis.
# - Identifying any constraints or limitations in your data or analytical capabilities.
# - Performing a **gap analysis**--compare your ideal analysis scenario with what's actually possible given your current resources and data.
# - Develop strategies to address any identified gaps, such as collecting additional data or employing advanced analytical techniques.
#
# For Juicy Lucy's, you might realize that while you have extensive sales data, you lack information on customer sentiment beyond the "Rate-Your-Burp" app. This could lead to a proposal for implementing a more comprehensive customer feedback system.
#
# By following this process, you'll be well-equipped to choose the most appropriate type of analysis for your specific business questions. Whether you end up performing trend analysis, exploratory data analysis, or any other technique, you'll have a solid foundation to ensure your analysis is focused, relevant, and actionable.
#
# In the next sections, we'll dive into specific types of analysis, starting with a description of the SQL Data Warehouse that will serve as the foundation for our examples with Juicy Lucy's Gourmet Burger Emporium.

# %% [markdown]
# ## What Does Our Data Warehouse Look Like?
#
# In the world of data analysis, a **data warehouse** serves as a central repository of integrated data from various sources. For Juicy Lucy's Gourmet Burger Emporium, we've designed a SQL-based data warehouse to store and manage all relevant business data. This warehouse will be the foundation for our analyses throughout this chapter. While we won't be querying this warehouse directly, this is where the data would "live" in a real world setting.
#
# ### Data Warehouse Structure
#
# Our data warehouse consists of several interconnected tables, each representing a different aspect of Juicy Lucy's operations. Here's an overview of the main tables:
#
# 1. `Restaurants`: Information about each Juicy Lucy's location, including address, opening date, and seating capacity.
#
# 2. `Menu_Items`: Details about every item on Juicy Lucy's menu, including name, description, category, and base price.
#
# 3. `Customers`: Data on registered customers, including contact information and loyalty program status.
#
# 4. `Orders`: Records of each transaction, linking to the customer (if known) and the restaurant where the order was placed.
#
# 5. `Order_Details`: Breakdown of each order into individual menu items, recording quantity and price paid.
#
# 6. `Employee`: Information about Juicy Lucy's staff, including their role and primary work location.
#
# 7. `Inventory`: Tracks stock levels of ingredients at each restaurant.
#
# 8. `Promotions`: Details about marketing campaigns and special offers, including start and end dates.
#
# 9. `Customer_Feedback`: Stores ratings and comments from the "Rate-Your-Burp" app and other feedback channels.
#
# In practice, data analysts would need to retrieve data from this warehouse using SQL queries. However, for the purposes of our examples in this textbook, we'll provide the necessary data directly in the form of pandas DataFrames. This approach allows us to focus on the analysis techniques rather than the intricacies of SQL querying.
#
# It's important to remember that real-world data warehouses are often much more complex, with additional tables, views, and stored procedures. They may also employ techniques like **dimensional modeling** to optimize query performance and facilitate analysis.
#
# When working with a data warehouse, analysts must consider several factors:
#
# 1. **Data freshness**. How often is the data updated? For Juicy Lucy's, sales data might be refreshed nightly, while inventory data could be updated in real-time.
#
# 2. **Data quality**. Are there processes in place to ensure data accuracy and completeness? For instance, how are missing customer names in orders handled?
#
# 3. **Data granularity**. At what level of detail is the data stored? Our `Order_Details` table, for example, allows for analysis at the individual menu item level.
#
# 4. **Data relationships**. Understanding how tables are related is crucial for accurate analysis. For example, linking `Orders` to `Customers` allows us to analyze purchasing patterns of individual customers.
#
# As we progress through this chapter, we'll use subsets of this data warehouse to demonstrate various analysis techniques. By working with this fictional but realistic dataset, you'll gain practical experience in applying data analysis methods to solve business problems.

# %% [markdown]
# ## How Can We Identify and Analyze Trends in Our Data?
#
# **Trend analysis** is a crucial technique in data science that helps businesses understand patterns and changes in their data over time. For Juicy Lucy's Gourmet Burger Emporium, trend analysis can provide valuable insights into sales patterns, customer behavior, and the effectiveness of promotions.
#
# Let's walk through the trend analysis process using a real example from Juicy Lucy's.
#
# ### Step 1: Define the metric and time frame
#
# Clearly specify what you want to measure and over what period. This step is crucial as it sets the foundation for your analysis.
#
# Example: Let's analyze monthly sales of Juicy Lucy's signature "Minnesotan Madness" burger over the past year.
#
# ### Step 2: Collect and prepare the data
#
# Gather the relevant data from your data warehouse or other sources. This often involves writing SQL queries or using data extraction tools. Once collected, clean the data by handling missing values, removing duplicates, and ensuring consistent formatting.
#
# Example: Let's create a sample dataset representing our monthly sales data:

# %%
import pandas as pd
import numpy as np

# set seed
np.random.seed(52179)

# Create date range for the past three years (36 months)
date_range = pd.date_range(end=pd.Timestamp.now(), periods=36, freq='M')

# Generate sample sales data with a general upward trend and some seasonality
base_sales = 1000 + np.arange(36) * 50  # Upward trend
seasonality = np.sin(np.arange(36) * 2 * np.pi / 12) * 200  # Seasonal component
noise = np.random.normal(0, 50, 36)  # Random noise

sales = base_sales + seasonality + noise

# Create the DataFrame
df_sales = pd.DataFrame({
    'Date': date_range,
    'Sales': sales.astype(int)
})

df_sales.head()
# Out:
# <ipython-input-1-ed26fe0f62f4>:8: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   date_range = pd.date_range(end=pd.Timestamp.now(), periods=36, freq='M')
#                         Date  Sales
# 0 2021-10-31 18:44:28.791965   1051
# 1 2021-11-30 18:44:28.791965   1214
# 2 2021-12-31 18:44:28.791965   1296
# 3 2022-01-31 18:44:28.791965   1299
# 4 2022-02-28 18:44:28.791965   1355

# %% [markdown]
# This generates a DataFrame with monthly sales data, incorporating a general upward trend, seasonal fluctuations, and some random variation.
#
# ### Step 3: Visualize the data
#
# Create visual representations of your data to get an initial understanding of trends. Time series plots are particularly useful for trend analysis.
#
# Example: Let's create a line plot to visualize our sales data:

# %%
df_sales.plot(x='Date', y='Sales', kind='line', figsize=(12, 6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# This Seaborn lineplot provides a clear visualization of our sales data over time. The markers at each data point help to distinguish individual months, while the line connects the points to show the overall trend.
#
# ### Step 4: Identify patterns
#
# Examine your visualizations and data to identify consistent upward or downward movements, cyclical patterns, or seasonal variations. Look for any sudden changes or anomalies that might require further investigation.
#
# Example: From our plot, we can observe:
#
# -   A general upward trend in sales over the year
# -   Noticeable fluctuations, with peaks occurring around the summer months
# -   No significant anomalies or sudden changes
#
# ### Step 5: Apply statistical techniques
#
# Use statistical methods to quantify and confirm the trends you've observed visually. Common techniques include moving averages, exponential smoothing, and regression analysis.
#
# Example: Let's run a linear regression:

# %%
# Perform linear regression using statsmodels' formula API
import statsmodels.formula.api as smf
df_sales['Time'] = np.arange(len(df_sales))  # Creating a time variable
model = smf.ols('Sales ~ Time', data=df_sales).fit()

print(model.summary())
df_sales['Trend'] = model.fittedvalues
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     398.1
# Date:                Mon, 28 Oct 2024   Prob (F-statistic):           2.40e-20
# Time:                        18:44:30   Log-Likelihood:                -229.68
# No. Observations:                  36   AIC:                             463.4
# Df Residuals:                      34   BIC:                             466.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1062.3709     47.952     22.155      0.000     964.921    1159.821
# ...

# %% [markdown]
# This output shows the results of an Ordinary Least Squares (OLS) regression analysis on 36 months of sales data. Let's break down the key points:
#
# 1. The R-squared value of 0.921 indicates that our model explains 91.8% of the variance in sales. This is a very good fit, suggesting that time is a strong predictor of sales.
# 2.  The F-statistic (398.1) and its p-value (2.40e-20) indicate that our model is statistically significant. The extremely low p-value suggests it's highly unlikely these results occurred by chance.
# 3.  The 'Time' coefficient (47) represents the average increase in sales per time period (likely month). This positive value indicates an upward trend in sales.
# 4.  The intercept (1062) represents the estimated sales at the beginning of our time series (time = 0).
# 5.  The [0.025 0.975] column shows the 95% confidence intervals for our coefficients. For both the intercept and time coefficient, these intervals don't include zero, further confirming their statistical significance.
#
#
# In summary, this analysis reveals a strong, statistically significant upward trend in sales over the 36-month period. On average, sales increased by about 47 units per month. However, the low Durbin-Watson statistic suggests there might be additional time-dependent factors affecting sales that aren't captured by this simple linear trend.
#
# Now, let's create a plot of this the "trend line" of this regression alongside the actual sales data a smoothed "3-month moving average)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate 3-month moving average
df_sales['3_Month_MA'] = df_sales['Sales'].rolling(window=3).mean()

plt.figure(figsize=(12, 6))
sns.lineplot(data=df_sales, x='Date', y='Sales', marker='o', label='Actual Sales')
sns.lineplot(data=df_sales, x='Date', y='3_Month_MA', color='red', label='3-Month Moving Average')
sns.lineplot(data=df_sales, x='Date', y='Trend', color='green', label='Linear Trend')
plt.title("Monthly Sales Analysis")
plt.xlabel("Date")
plt.ylabel("Sales (units)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# This plot combines our original data, the 3-month moving average, and the linear trend line. The moving average smooths out short-term fluctuations, while the trend line shows the overall direction of sales over time.
#
# ### Step 6: Interpret results
#
# Analyze your findings in the context of the business and external factors. Consider how internal decisions or external events might have influenced the observed trends.
#
# Example: Interpreting our results:
#
# -   The "Minnesotan Madness" burger shows a clear upward trend in sales over the year.
# -   There's a noticeable seasonal pattern, with sales peaking in the summer months.
# -   The 3-month **moving average** confirms the overall growth while capturing seasonal variations.
# -   The linear trend line quantifies the average growth rate over time.
#
# ### Step 7: Make predictions
#
# Based on the identified trends, forecast future values if appropriate. This could involve simple extrapolation or more complex time series forecasting
# methods.
#
# Example: While we won't perform a detailed forecast here, we could use our linear trend to make a simple projection.

# %%
# use model to make prediction
# add future dates
future_dates = pd.date_range(start=df_sales['Date'].max(), periods=12, freq='ME')
df_sales = pd.concat([df_sales, pd.DataFrame({'Date': future_dates})])
df_sales['Forecast'] = model.predict(df_sales['Time'])
df_sales.tail().round(2)
# Out:
#                          Date  Sales  Time  Trend  3_Month_MA  Forecast
# 7  2025-04-30 18:44:28.791965    NaN   NaN    NaN         NaN   1391.44
# 8  2025-05-31 18:44:28.791965    NaN   NaN    NaN         NaN   1438.46
# 9  2025-06-30 18:44:28.791965    NaN   NaN    NaN         NaN   1485.47
# 10 2025-07-31 18:44:28.791965    NaN   NaN    NaN         NaN   1532.48
# 11 2025-08-31 18:44:28.791965    NaN   NaN    NaN         NaN   1579.49

# %% [markdown]
# By applying these trend analysis techniques, Juicy Lucy's can gain valuable insights into their sales patterns, helping them make informed decisions about inventory, marketing, and menu planning. For instance, they might consider:
#
# - Ensuring adequate supply chain capacity to meet the increasing demand
# - Developing special promotions or variations of the "Minnesotan Madness" burger for the summer months
# - Using the sales projections to set targets and plan for future growth

# %% [markdown]
# ## Student Exercise 1: Analyzing Customer Satisfaction Trends at Juicy Lucy's
#
# As a data analyst at Juicy Lucy's Gourmet Burger Emporium, you've been tasked with analyzing customer satisfaction trends. The restaurant collects satisfaction scores (0-10) from customer feedback forms after each visit. Understanding these patterns will help improve service quality and customer retention.
#
# ## Your Task
# Follow the steps below to analyze customer satisfaction trends over the past three years. You'll use Python to generate, visualize, and analyze the data.
#
# ### Step 1: Define the metric and time frame
# - We'll analyze monthly average customer satisfaction scores
# - Time period: Past 36 months
# - Scoring system: 0-10 scale
#
# ### Step 2: Generate and Prepare the Data
# Run the code below to create your dataset:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Set seed for reproducibility
np.random.seed(52179)

# Create date range for the past three years (36 months)
date_range = pd.date_range(end=pd.Timestamp.now(), periods=36, freq='ME')

# Generate sample satisfaction scores with:
# - A slight upward trend (improvement over time)
# - Seasonal variations (lower in busy summer months)
# - Random noise

# Base satisfaction starting at 7.0 with small improvements over time
base_satisfaction = 7.0 + np.arange(36) * 0.02

# Add seasonal effect (lower scores during busy summer months)
seasonality = -np.sin(np.arange(36) * 2 * np.pi / 12) * 0.3

# Add random noise
noise = np.random.normal(0, 0.2, 36)

# Combine components
satisfaction = base_satisfaction + seasonality + noise

# Ensure scores stay within 0-10 range
satisfaction = np.clip(satisfaction, 0, 10)

# Create the DataFrame
df_satisfaction = pd.DataFrame({
    'Date': date_range,
    'Satisfaction': satisfaction
})

df_satisfaction.head()
# Out:
#                         Date  Satisfaction
# 0 2021-10-31 18:44:30.908993      7.205787
# 1 2021-11-30 18:44:30.908993      7.128929
# 2 2021-12-31 18:44:30.908993      6.873279
# 3 2022-01-31 18:44:30.908993      6.557206
# 4 2022-02-28 18:44:30.908993      6.751019

# %%
df_satisfaction.describe().round(2)
# Out:
#                                 Date  Satisfaction
# count                             36         36.00
# mean   2023-04-16 16:04:30.908992512          7.39
# min       2021-10-31 18:44:30.908993          6.56
# 25%    2022-07-24 00:44:30.908993024          7.01
# 50%    2023-04-15 18:44:30.908993024          7.40
# 75%    2024-01-08 12:44:30.908993024          7.58
# max       2024-09-30 18:44:30.908993          8.33
# std                              NaN          0.41

# %% [markdown]
# ### Step 3: Visualization Tasks
# 1. Create a line plot showing satisfaction scores over time
# 2. Add markers to show individual data points
# 3. Include appropriate labels and title
# 4. Add a grid for better readability

# %% [markdown]
# ### Step 4: Pattern Analysis
# Examine your visualization and answer these questions:
# 1. Is there an overall trend in customer satisfaction?
# 2. Are there any seasonal patterns?
# 3. Can you identify any unusual spikes or dips?
# 4. What might explain the patterns you observe?

# %% [markdown]
# ### Step 5: Statistical Analysis
# 1. Calculate and add a 3-month moving average to smooth out short-term fluctuations
# 2. Perform a linear regression analysis to quantify the trend
# 3. Create a visualization showing:
#    - Original satisfaction scores
#    - Moving average
#    - Trend line
# 4. Calculate key statistics:
#    - Average satisfaction score
#    - Standard deviation
#    - Minimum and maximum scores
#    - Trend coefficient (how much satisfaction changes per month on average)

# %% [markdown]
# ### Step 6: Interpretation
# Write a brief report (250-300 words) that:
# 1. Summarizes the key findings from your analysis
# 2. Explains what the trends and patterns might mean for the business
# 3. Suggests at least three specific recommendations based on your findings

# %% [markdown]
# ## How Can We Evaluate and Compare Performance Across Different Metrics?
#
# **Performance analysis** is a critical technique in data science that allows businesses to assess how well they're meeting their goals and objectives. For Juicy Lucy's Gourmet Burger Emporium, performance analysis can help identify top-performing products, evaluate restaurant efficiency, and pinpoint areas for improvement.
#
# Let's walk through the performance analysis process using examples from Juicy Lucy's.
#
# ### Step 1: Define Key Performance Indicators (KPIs)
#
# Identify the specific metrics (**key performance indicators**) that best represent success for your business. These KPIs should align with your overall business objectives.
#
# Example: For Juicy Lucy's, let's focus on three KPIs:
# 1. Average daily sales per restaurant
# 2. Customer satisfaction rating
# 3. Food waste percentage
#
# ### Step 2: Collect and prepare the data
#
# Gather the relevant data for your chosen KPIs. This may involve querying multiple tables in your data warehouse and joining the results.
#
# Example: Let's create a sample dataset with these KPIs for Juicy Lucy's restaurants:

# %%
# Create sample data
np.random.seed(52179)
restaurants = ['Minneapolis', 'St. Paul', 'Duluth', 'Rochester', 'Bloomington']
dates = pd.date_range(start='2023-01-01', periods=30, freq='D')

# Define biases for each restaurant
biases = {
    'Minneapolis': {'sales_mean': 6000, 'sales_std': 800, 'satisfaction_min': 4, 'satisfaction_max': 5, 'waste_min': 3, 'waste_max': 8},
    'St. Paul': {'sales_mean': 5000, 'sales_std': 1000, 'satisfaction_min': 4.5, 'satisfaction_max': 5, 'waste_min': 4, 'waste_max': 9},
    'Duluth': {'sales_mean': 4500, 'sales_std': 900, 'satisfaction_min': 3.5, 'satisfaction_max': 4.5, 'waste_min': 2, 'waste_max': 6},
    'Rochester': {'sales_mean': 5200, 'sales_std': 950, 'satisfaction_min': 3.8, 'satisfaction_max': 4.7, 'waste_min': 5, 'waste_max': 10},
    'Bloomington': {'sales_mean': 4800, 'sales_std': 850, 'satisfaction_min': 4, 'satisfaction_max': 4.8, 'waste_min': 3, 'waste_max': 7},
}

data = {
    'Restaurant': [],
    'Date': [],
    'Avg_Daily_Sales': [],
    'Customer_Satisfaction': [],
    'Food_Waste_Pct': []
}

# Generate data
for date in dates:
    for restaurant in restaurants:
        params = biases[restaurant]
        data['Restaurant'].append(restaurant)
        data['Date'].append(date)
        data['Avg_Daily_Sales'].append(np.random.normal(params['sales_mean'], params['sales_std']))
        data['Customer_Satisfaction'].append(np.random.uniform(params['satisfaction_min'], params['satisfaction_max']))
        data['Food_Waste_Pct'].append(np.random.uniform(params['waste_min'], params['waste_max']))

df_performance = pd.DataFrame(data)
df_performance['Avg_Daily_Sales'] = df_performance['Avg_Daily_Sales'].astype(int)
df_performance['Customer_Satisfaction'] = df_performance['Customer_Satisfaction'].round(2)
df_performance['Food_Waste_Pct'] = df_performance['Food_Waste_Pct'].round(2)

df_performance.head()
# Out:
#     Restaurant       Date  Avg_Daily_Sales  Customer_Satisfaction  \
# 0  Minneapolis 2023-01-01             6823                   4.17
# 1     St. Paul 2023-01-01             6294                   4.91
# 2       Duluth 2023-01-01             3910                   3.61
# 3    Rochester 2023-01-01             5844                   4.25
# 4  Bloomington 2023-01-01             3598                   4.35
#
#    Food_Waste_Pct
# 0            6.26
# 1            4.79
# 2            4.93
# 3            8.22
# 4            3.32

# %% [markdown]
# This creates a DataFrame with performance data for five Juicy Lucy's restaurants over a 15-day period.
#
# ### Step 3: Calculate summary statistics
# Compute relevant summary statistics to get an overall view of performance across your KPIs.
#
# Example: Let's calculate mean performance for each restaurant:

# %%
summary_stats = df_performance.groupby('Restaurant').agg({
    'Avg_Daily_Sales': 'mean',
    'Customer_Satisfaction': 'mean',
    'Food_Waste_Pct': 'mean'
}).round(2)

summary_stats
# Out:
#              Avg_Daily_Sales  Customer_Satisfaction  Food_Waste_Pct
# Restaurant
# Bloomington          4804.00                   4.35            4.89
# Duluth               4760.37                   3.91            4.22
# Minneapolis          5968.07                   4.47            5.51
# Rochester            5084.03                   4.23            7.69
# St. Paul             5388.73                   4.76            6.76

# %% [markdown]
# This gives us a quick overview of how each restaurant is performing across our KPIs.
#
# ### Step 4: Visualize the data
#
# Create visual representations to help identify patterns, trends, and outliers in your performance data.
#
# Example: Let's create a multi-metric visualization for our restaurants. In order to make this work, we'll need to **normalize** them (so that all the metrics are on a similar scale.

# %%
# Normalize the metrics
df_normalized = df_performance.copy()
df_normalized['Avg_Daily_Sales'] = (df_normalized['Avg_Daily_Sales'] - df_normalized['Avg_Daily_Sales'].min()) / (df_normalized['Avg_Daily_Sales'].max() - df_normalized['Avg_Daily_Sales'].min())
df_normalized['Customer_Satisfaction'] = (df_normalized['Customer_Satisfaction'] - df_normalized['Customer_Satisfaction'].min()) / (df_normalized['Customer_Satisfaction'].max() - df_normalized['Customer_Satisfaction'].min())
df_normalized['Food_Waste_Pct'] = (df_normalized['Food_Waste_Pct'] - df_normalized['Food_Waste_Pct'].min()) / (df_normalized['Food_Waste_Pct'].max() - df_normalized['Food_Waste_Pct'].min())

# drop date
df_normalized = df_normalized.drop('Date', axis=1)

# Compute summary statistics excluding the 'Date' column
summary_stats_norm = df_normalized.groupby('Restaurant').mean().reset_index()

# Melt the DataFrame to long format for easier plotting
df_melted = pd.melt(summary_stats_norm, id_vars=['Restaurant'], var_name='Metric', value_name='Value')

df_melted
# Out:
#      Restaurant                 Metric     Value
# 0   Bloomington        Avg_Daily_Sales  0.547062
# 1        Duluth        Avg_Daily_Sales  0.539025
# 2   Minneapolis        Avg_Daily_Sales  0.761478
# 3     Rochester        Avg_Daily_Sales  0.598643
# 4      St. Paul        Avg_Daily_Sales  0.654768
# 5   Bloomington  Customer_Satisfaction  0.570805
# 6        Duluth  Customer_Satisfaction  0.268046
# 7   Minneapolis  Customer_Satisfaction  0.656092
# 8     Rochester  Customer_Satisfaction  0.488276
# 9      St. Paul  Customer_Satisfaction  0.856092
# 10  Bloomington         Food_Waste_Pct  0.342119
# 11       Duluth         Food_Waste_Pct  0.253554
# 12  Minneapolis         Food_Waste_Pct  0.423223
# 13    Rochester         Food_Waste_Pct  0.712141
# 14     St. Paul         Food_Waste_Pct  0.589139

# %% [markdown]
# ### Bar Graph: Normalized Key Performance Indicators

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create the plot
plt.figure(figsize=(12, 6))
sns.barplot(data=df_melted, x='Restaurant', y='Value', hue='Metric')
plt.title("Performance Metrics by Restaurant")
plt.xticks(rotation=45)
plt.legend(title='Metric', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# This plot allows us to compare all three metrics across restaurants simultaneously.
#
# ### Step 5: Identify top performers and areas for improvement
#
# Analyze your visualizations and summary statistics to determine which units are performing well and which may need attention.
#
# Example: From our summary and visualization, we can observe:
#
# -   Minneapolis seems to have the highest average daily sales
# -   St. Paul has the highest customer satisfaction rating
# -   Duluth has the lowest food waste percentage
#
# ### Step 6: Perform comparative analysis
#
# Compare performance across different dimensions (e.g., time, location) to gain deeper insights.
#
# Example: Let's compare daily sales performance over time for our top and bottom performing restaurants:

# %%
top_restaurant = summary_stats['Avg_Daily_Sales'].idxmax()
bottom_restaurant = summary_stats['Avg_Daily_Sales'].idxmin()

plt.figure(figsize=(12, 6))
for restaurant in [top_restaurant, bottom_restaurant]:
    data = df_performance[df_performance['Restaurant'] == restaurant]
    sns.lineplot(data=data, x='Date', y='Avg_Daily_Sales', label=restaurant)

plt.title("Daily Sales Comparison: Top vs Bottom Performing Restaurants")
plt.xlabel("Date")
plt.ylabel("Average Daily Sales ($)")
plt.legend(title='Restaurant')
plt.grid(True)
plt.show()

# %% [markdown]
# This allows us to see how the top and bottom performers compare over time, potentially revealing patterns or anomalies.
#
# ### Step 7: Interpret results and make recommendations
#
# Based on your analysis, draw conclusions about overall performance and suggest actionable steps for improvement.
#
# Example: Interpreting our results for Juicy Lucy's:
#
# Depending on the results of our analysis, we might conclude things like:
#
# - Minneapolis is leading in sales, but has room for improvement in customer satisfaction and food waste reduction.
#
# - St Paul's high customer satisfaction could be studied and potentially replicated at other locations.
#
# - Duluth's low food waste practices should be examined and possibly implemented across other restaurants.
#
# Recommendations:
#
# 1. Conduct a best practices study at the St. Paul location to understand drivers of high customer satisfaction.
#
# 2. Implement food waste reduction strategies from Duluth across all locations.
#
# 3. Investigate reasons for lower sales in Duluth and Bloomington, possibly through customer surveys or market analysis.
#
# By applying these performance analysis techniques, Juicy Lucy's can gain a comprehensive understanding of how different aspects of their business are performing. This information can guide strategic decisions, help allocate resources effectively, and drive continuous improvement across the restaurant chain.

# %% [markdown]
# ## Student Exercise 2: Analyzing Menu Performance Across Restaurant Locations
#
# You're a data analyst at Juicy Lucy's Gourmet Burger Emporium, and management wants to understand how different menu items perform across their locations. This analysis will help optimize the menu and identify opportunities for improvement.
#
# ### Your Task
# You'll analyze three key metrics for each menu item across different locations:
# - Profit margin percentage
# - Order frequency (percentage of total orders)
# - Preparation time (minutes)
#
# ### Dataset Generation
# Complete the code below to create your analysis dataset:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Set seed for reproducibility
np.random.seed(52179)

# Define locations and menu items
locations = ['Minneapolis', 'St. Paul', 'Duluth', 'Rochester', 'Bloomington']
menu_items = ['Classic Lucy', 'Spicy Jalapeno', 'Mushroom Swiss',
              'Veggie Delight', 'BBQ Bacon']

# Generate 30 days of data
dates = pd.date_range(start='2024-01-01', periods=30, freq='D')

# Define base characteristics for each menu item
item_characteristics = {
    'Classic Lucy':     {'margin_base': 65, 'order_freq_base': 30, 'prep_time_base': 8},
    'Spicy Jalapeno':  {'margin_base': 70, 'order_freq_base': 20, 'prep_time_base': 10},
    'Mushroom Swiss':  {'margin_base': 68, 'order_freq_base': 15, 'prep_time_base': 12},
    'Veggie Delight':  {'margin_base': 75, 'order_freq_base': 15, 'prep_time_base': 9},
    'BBQ Bacon':       {'margin_base': 62, 'order_freq_base': 20, 'prep_time_base': 11}
}

# Create empty lists to store data
all_data = []

# Generate data for each location, date, and menu item
for location in locations:
    # Create location-specific variations (some locations perform slightly differently)
    location_bias = np.random.normal(1, 0.1)  # Random bias for each location

    for date in dates:
        # Create daily variations
        daily_bias = np.random.normal(1, 0.05)  # Small random daily variation

        # Initialize order frequency adjustments for this day
        freq_adjustments = {}

        # First pass: generate initial frequencies
        for item in menu_items:
            base_chars = item_characteristics[item]

            # Generate raw order frequency with variation
            freq_raw = base_chars['order_freq_base'] * location_bias * daily_bias * \
                      np.random.normal(1, 0.1)
            freq_adjustments[item] = freq_raw

        # Normalize frequencies to sum to 100%
        freq_sum = sum(freq_adjustments.values())
        for item in freq_adjustments:
            freq_adjustments[item] = (freq_adjustments[item] / freq_sum) * 100

        # Generate final data for each menu item
        for item in menu_items:
            base_chars = item_characteristics[item]

            # Generate metrics with appropriate variation
            margin = base_chars['margin_base'] * location_bias * daily_bias * \
                    np.random.normal(1, 0.05)  # 5% variation in margins

            order_freq = freq_adjustments[item]  # Use normalized frequency

            prep_time = base_chars['prep_time_base'] * location_bias * daily_bias * \
                       np.random.normal(1, 0.1)  # 10% variation in prep time

            # Append the data
            all_data.append({
                'Date': date,
                'Location': location,
                'Menu_Item': item,
                'Profit_Margin': round(margin, 2),
                'Order_Frequency': round(order_freq, 2),
                'Prep_Time': round(prep_time, 2)
            })

# Create DataFrame
df = pd.DataFrame(all_data)
df.head()
# Out:
#         Date     Location       Menu_Item  Profit_Margin  Order_Frequency  \
# 0 2024-01-01  Minneapolis    Classic Lucy          78.92            32.03
# 1 2024-01-01  Minneapolis  Spicy Jalapeno          80.07            18.33
# 2 2024-01-01  Minneapolis  Mushroom Swiss          80.17            14.77
# 3 2024-01-01  Minneapolis  Veggie Delight          84.07            15.80
# 4 2024-01-01  Minneapolis       BBQ Bacon          72.36            19.07
#
#    Prep_Time
# 0       9.68
# 1      14.36
# 2      12.10
# 3       9.72
# 4      12.20

# %%
df.describe().round(2)
# Out:
#                                 Date  Profit_Margin  Order_Frequency  \
# count                            750         750.00           750.00
# mean   2024-01-15 11:59:59.999999744          70.46            20.00
# min              2024-01-01 00:00:00          50.59            10.60
# 25%              2024-01-08 00:00:00          63.93            15.36
# 50%              2024-01-15 12:00:00          70.02            18.92
# 75%              2024-01-23 00:00:00          76.67            22.30
# max              2024-01-30 00:00:00          97.82            34.61
# std                              NaN           8.78             5.76
#
#        Prep_Time
# count     750.00
# mean       10.35
# min         5.53
# 25%         8.85
# 50%        10.24
# 75%        11.78
# max        17.21
# std         2.05

# %% [markdown]
# ### Step 2. Summary Statistics
# - Calculate the following for each menu item at each location:
#   * Average profit margin
#   * Average order frequency
#   * Average preparation time
#   * Standard deviation for each metric
# - Create a summary table showing these statistics

# %% [markdown]
# ### Step 3. Visualization
# Create three visualizations:
# 1. A normalized metrics comparison (similar to the example)
# 2. A heatmap showing performance across locations
# 3. A time series plot showing how metrics change over the 30-day period

# %% [markdown]
# ### Step 4. Performance Analysis
# Answer the following questions:
# 1. Which menu items are most profitable at each location?
# 2. Is there a relationship between preparation time and order frequency?
# 3. How does the performance of the 'Veggie Delight' compare across different locations?
# 4. Are there any noticeable patterns or trends in the data?

# %% [markdown]
# ### Step 5: Recommendations
# Write a brief report (300-400 words) that includes:
# 1. Three specific recommendations based on your analysis
# 2. Potential reasons for performance variations
# 3. Suggested actions for improvement

# %% [markdown]
# ## How Can We Uncover Insights and Patterns in Our Food Safety Data?
#
# **Exploratory Data Analysis (EDA)** is a crucial approach in data science that involves analyzing and summarizing datasets to uncover patterns, spot anomalies, test hypotheses, and check assumptions. For Juicy Lucy's Gourmet Burger Emporium, EDA can reveal valuable insights about food safety and quality control.
#
# Let's walk through the EDA process using a simplified food safety dataset for Juicy Lucy's.
#
# ### Step 1: Define the objective
#
# Clearly state the purpose of your exploratory analysis. What questions are you trying to answer?
#
# Example: For Juicy Lucy's food safety data, let's explore the following questions:
#
# 1.  What is the overall distribution of bacterial counts in our food samples?
# 2.  Is there a relationship between storage temperature and bacterial growth?
# 3.  How does the time since preparation affect food safety metrics?
#
# ### Step 2: Collect and prepare the data
#
# Gather relevant data and prepare it for analysis. This often involves data cleaning and formatting.
#
# Example: Let's create a sample dataset for Juicy Lucy's food safety inspections:

# %%
np.random.seed(52179)

# Create sample data
n_samples = 200
data = {
    'Sample_ID': range(1, n_samples + 1),
    'Storage_Temp_C': np.random.uniform(2, 8, n_samples),
    'Time_Since_Prep_Hours': np.random.uniform(0, 48, n_samples),
    'Bacterial_Count': np.exp(np.random.uniform(0, 5, n_samples))  # Log-normal distribution
}

df_food_safety = pd.DataFrame(data)

# Add some correlation (with noise) between variables
df_food_safety['Bacterial_Count'] += 100 * df_food_safety['Storage_Temp_C'] + \
                                     10 * df_food_safety['Time_Since_Prep_Hours'] + \
                                     np.random.normal(0, 500, n_samples)

# insert random nulls
df_food_safety['Storage_Temp_C'] = np.where(np.random.rand(n_samples) < 0.03, np.nan, df_food_safety['Storage_Temp_C'])
df_food_safety['Time_Since_Prep_Hours'] = np.where(np.random.rand(n_samples) < 0.03, np.nan, df_food_safety['Time_Since_Prep_Hours'])
df_food_safety['Bacterial_Count'] = np.where(np.random.rand(n_samples) < 0.03, np.nan, df_food_safety['Bacterial_Count'])


df_food_safety['Bacterial_Count'] = np.maximum(0, df_food_safety['Bacterial_Count'])

df_food_safety.head()
# Out:
#    Sample_ID  Storage_Temp_C  Time_Since_Prep_Hours  Bacterial_Count
# 0          1        2.073949               2.181446       230.849522
# 1          2        2.577043              36.180780       828.884487
# 2          3        6.185439              28.733929      1233.290012
# 3          4        5.942141              31.841452       870.553008
# 4          5        3.002649              43.190953       254.410448

# %% [markdown]
# This creates a DataFrame with food safety data including storage temperature, time since preparation, and bacterial count.
#
# ### Step 3: Perform initial data exploration
#
# Start with basic statistical summaries to get a feel for your data.
#
# Example: Let's generate a summary of our food safety data:

# %%
df_food_safety.describe().round(2)
# Out:
#        Sample_ID  Storage_Temp_C  Time_Since_Prep_Hours  Bacterial_Count
# count     200.00          195.00                 193.00           195.00
# mean      100.50            4.99                  23.55           784.17
# std        57.88            1.66                  14.00           520.95
# min         1.00            2.06                   0.31             0.00
# 25%        50.75            3.47                  11.09           351.39
# 50%       100.50            4.94                  24.08           776.10
# 75%       150.25            6.43                  36.18          1083.86
# max       200.00            7.99                  47.84          2384.17

# %%
df_food_safety.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sample_ID              200 non-null    int64
#  1   Storage_Temp_C         195 non-null    float64
#  2   Time_Since_Prep_Hours  193 non-null    float64
#  3   Bacterial_Count        195 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 6.4 KB

# %% [markdown]
# At this stage of the EDA, we are concerned with things like **data types**, **missing data**, and **basic descriptive statistics**. Here are a few things that might stand out:
#
# 1.  *Data Types and Non-Null Counts*
#
#     -   The `info()` method shows that we have four columns: `Sample_ID`, `Storage_Temp_C`, `Time_Since_Prep_Hours`, and `Bacterial_Count`.
#     -   The columns have appropriate data types: `Sample_ID` is an integer, while the others are floats. This ensures numerical operations can be performed correctly.
# 2.  *Missing Data*
#
#     -   The `info()` method reveals missing data: `Storage_Temp_C` has 195 non-null entries, and `Time_Since_Prep_Hours` has 193, indicating some missing values.
#     -   Identifying missing data is crucial as it might require imputation or removal depending on the analysis.
# 3.  *Descriptive Statistics*
#
#     -   The `describe()` method provides statistics like mean, standard deviation, min, and max for the numerical columns.
#     -   For example, the mean and standard deviation of `Bacterial_Count` can give insights into the average bacterial levels and their variability across samples.
# 4.  *Data Range and Distribution*
#
#     -   The `min` and `max` values for `Storage_Temp_C` and `Time_Since_Prep_Hours` help understand the range of temperatures and preparation times.
#     -   Percentiles (25%, 50%, 75%) offer a sense of the distribution and central tendency, which is useful for identifying outliers or unusual patterns.
#
# By examining these aspects, students gain a foundational understanding of the dataset's structure, quality, and initial characteristics.

# %% [markdown]
# This gives us an overview of our dataset, including distributions of variables, any missing values, and data types.
#
# ### Step 4: Visualize distributions
#
# Create visualizations to understand the distribution of individual variables.
#
# Example: Let's create histograms for our main variables:

# %%
df_food_safety.hist(figsize=(12, 8))
plt.tight_layout()
plt.show()

# %% [markdown]
# These histograms help us understand the shape and range of our variables. Note that we've included both the bacterial count and its logarithm due to its skewed nature.
#
# ### Step 5: Explore relationships between variables
#
# Create scatter plots and correlation matrices to understand how variables relate to each other.
#
# Example: Let's visualize relationships between our variables:

# %% [markdown]
# ### Graphic: Scatter-plot matrix
# A **scatter plot matrix** is a great way to see the potential correlations between different pairs of numerical variables in your data set.

# %%
# Scatter plot matrix
sns.pairplot(df_food_safety[['Bacterial_Count','Storage_Temp_C','Time_Since_Prep_Hours']], corner=True)
plt.suptitle('Scatter Plot Matrix of Food Safety Variables', y=1.02)
plt.show()

# %% [markdown]
# ### Graphic: Correlation Heatmap
# A **heatmap** is a another graphic often used to show the strength of correlation between different variables. Usually, darker colors indicate stronger correlations.

# %%
# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_food_safety.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap of Food Safety Variables')
plt.show()

# %% [markdown]
# These visualizations help us see potential relationships between variables, such as how bacterial count might be affected by storage temperature and time since preparation.
#
# ### Step 6: Investigate patterns and anomalies
#
# Dive deeper into interesting patterns or anomalies discovered in the previous steps.
#
# Example: Let's investigate the relationship between storage temperature and bacterial count:

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_food_safety, x='Storage_Temp_C', y='Bacterial_Count',
                hue='Time_Since_Prep_Hours', palette='viridis')
plt.title('Bacterial Count vs. Storage Temperature')
plt.xlabel('Storage Temperature (°C)')
plt.ylabel('Bacterial Count')
plt.yscale('log')  # Use log scale for bacterial count
plt.show()

# %% [markdown]
# This plot helps us visualize how bacterial count varies with storage temperature, while also considering the time since preparation.
#
# ### Step 7: Perform basic statistical tests
#
# Conduct simple statistical tests to quantify relationships and differences in your data.
#
# Example: Let's perform a correlation test between storage temperature and bacterial count:

# %%
from scipy import stats

# drop all null rows
df_food_safety = df_food_safety.dropna()

correlation, p_value = stats.pearsonr(df_food_safety['Storage_Temp_C'],
                                      df_food_safety['Bacterial_Count'])

print(f"Correlation between Storage Temperature and Bacterial Count:")
print(f"Correlation coefficient: {correlation:.3f}")
print(f"P-value: {p_value:.3e}")
# Out:
# Correlation between Storage Temperature and Bacterial Count:
# Correlation coefficient: 0.391
# P-value: 4.253e-08

# %% [markdown]
# As we can see from the low p-value, there is defininitely a correlation between storage temp and bacterial count!

# %% [markdown]
# This test helps us quantify the strength and significance of the relationship between storage temperature and bacterial count.
#
# ### Step 8: Summarize findings and generate insights
#
# Compile your key findings and translate them into actionable insights for the business.
#
# Example: Based on our exploratory analysis of Juicy Lucy's food safety data, we can conclude:
#
# 1.  Bacterial counts show a right-skewed distribution, with a long tail of high values. This suggests that while most samples have low bacterial counts, there are some instances of very high counts that require attention.
# 2.  There's a positive correlation between storage temperature and bacterial count (correlation coefficient ≈ 0.5, p < 0.001). This indicates that higher storage temperatures are associated with higher bacterial growth.
# 3.  Time since preparation also shows a positive relationship with bacterial count, though the relationship appears weaker than with storage temperature.
# 4.  The scatter plot reveals that samples with both high storage temperatures and long times since preparation tend to have the highest bacterial counts.
#
# Recommendations:
#
# 1.  Implement stricter controls on storage temperature, aiming to keep it consistently below 5°C.
# 2.  Establish a maximum time limit for how long prepared food can be stored before it must be discarded.
# 3.  Develop a risk scoring system based on both storage temperature and time since preparation to prioritize food safety checks.
# 4.  Investigate samples with unusually high bacterial counts to identify any other contributing factors not captured in this dataset.
#
# By applying these EDA techniques, Juicy Lucy's can gain a deeper understanding of their food safety practices and identify key areas for improvement. These insights can inform storage procedures, preparation schedules, and quality control measures to ensure the highest standards of food safety.

# %% [markdown]
# ## Student Exercise 3: Understanding Customer Experience Through Data
#
# As a data analyst at Juicy Lucy's Gourmet Burger Emporium, you've been asked to analyze customer feedback data to improve the dining experience. You'll explore customer ratings, wait times, order values, and written feedback to identify patterns and opportunities for improvement.
#
# ### Dataset Generation
# Use the following code to generate your dataset:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# Set random seed for reproducibility
np.random.seed(52179)

# Generate sample data
n_samples = 300

# Create base data
df_feedback = pd.DataFrame({
    'Date': pd.date_range(start='2024-01-01', periods=n_samples),
    'Order_Value': np.random.normal(25, 8, n_samples),  # Average order $25
    'Wait_Time_Min': np.random.exponential(15, n_samples),  # Most waits around 15 min
    'Overall_Rating': np.random.normal(4.2, 0.8, n_samples),  # Most ratings around 4.2
    'Food_Quality': np.random.normal(4.3, 0.7, n_samples),
    'Service_Rating': np.random.normal(4.1, 0.9, n_samples),
    'Ambiance_Rating': np.random.normal(3.9, 0.6, n_samples)
})

# Add some realistic relationships
df_feedback['Overall_Rating'] += -0.3 * (df_feedback['Wait_Time_Min'] > 30).astype(int)  # Penalty for long waits
df_feedback['Service_Rating'] += -0.4 * (df_feedback['Wait_Time_Min'] > 30).astype(int)  # Bigger penalty on service

# Add time of day
df_feedback['Time_of_Day'] = np.random.choice(
    ['Lunch', 'Dinner', 'Late Night'],
    n_samples,
    p=[0.4, 0.5, 0.1]
)

# Add weekend/weekday
df_feedback['Is_Weekend'] = df_feedback['Date'].dt.weekday >= 5

# Add common feedback topics
feedback_options = [
    'Great service!',
    'Food was cold',
    'Long wait time',
    'Amazing burgers',
    'Friendly staff',
    'Slow service',
    'Perfect temperature',
    'Order was incorrect',
    'Excellent value',
    'Too noisy'
]

df_feedback['Written_Feedback'] = np.random.choice(
    feedback_options,
    n_samples,
    p=[0.25, 0.1, 0.1, 0.15, 0.1, 0.1, 0.05, 0.05, 0.05, 0.05]
)

# Clip ratings to valid range (1-5)
rating_columns = ['Overall_Rating', 'Food_Quality', 'Service_Rating', 'Ambiance_Rating']
for col in rating_columns:
    df_feedback[col] = np.clip(df_feedback[col], 1, 5)
    df_feedback[col] = df_feedback[col].round(1)

# Clip wait times to realistic values (0-120 minutes)
df_feedback['Wait_Time_Min'] = np.clip(df_feedback['Wait_Time_Min'], 0, 120)
df_feedback['Wait_Time_Min'] = df_feedback['Wait_Time_Min'].round(1)

# Clip order values to realistic values ($5-$100)
df_feedback['Order_Value'] = np.clip(df_feedback['Order_Value'], 5, 100)
df_feedback['Order_Value'] = df_feedback['Order_Value'].round(2)

# Add some missing values
numeric_columns = rating_columns + ['Wait_Time_Min', 'Order_Value']
for col in numeric_columns:
    mask = np.random.random(n_samples) < 0.03  # 3% missing values
    df_feedback.loc[mask, col] = np.nan

# %%
df_feedback.head()
# Out:
#         Date  Order_Value  Wait_Time_Min  Overall_Rating  Food_Quality  \
# 0 2024-01-01        33.23            7.2             NaN           3.8
# 1 2024-01-02        35.36           20.4             4.6           3.5
# 2 2024-01-03        28.72            2.7             4.3           4.7
# 3 2024-01-04        16.89            5.3             4.3           4.4
# 4 2024-01-05        22.23            8.5             4.9           NaN
#
#    Service_Rating  Ambiance_Rating Time_of_Day  Is_Weekend Written_Feedback
# 0             3.8              3.9       Lunch       False  Amazing burgers
# 1             4.5              4.0       Lunch       False   Great service!
# 2             3.4              4.5      Dinner       False  Excellent value
# 3             3.8              3.6       Lunch       False     Slow service
# 4             3.1              5.0      Dinner       False   Great service!

# %%
df_feedback.describe().round(2)
# Out:
#                       Date  Order_Value  Wait_Time_Min  Overall_Rating  \
# count                  300       286.00         300.00          290.00
# mean   2024-05-29 12:00:00        25.44          13.96            4.11
# min    2024-01-01 00:00:00         5.00           0.00            1.80
# 25%    2024-03-15 18:00:00        20.18           3.78            3.60
# 50%    2024-05-29 12:00:00        25.37           9.95            4.20
# 75%    2024-08-12 06:00:00        30.26          21.18            4.70
# max    2024-10-26 00:00:00        51.37          78.60            5.00
# std                    NaN         7.99          13.20            0.74
#
#        Food_Quality  Service_Rating  Ambiance_Rating
# count        292.00          290.00           290.00
# mean           4.24            4.03             3.89
# min            2.00            1.30             2.40
# 25%            3.80            3.50             3.50
# 50%            4.35            4.10             3.90
# ...

# %% [markdown]
# a) Examine the basic properties of the dataset:
# - Generate summary statistics for numeric ratings
# - Analyze the distribution of feedback across times of day
# - Check for missing values
# - Compare weekday vs weekend ratings
#
# b) Write a brief summary of your initial findings (100 words)

# %% [markdown]
# ### Step 2. Rating Analysis
# a) Create visualizations showing:
# - Distribution of all rating types (Overall, Food, Service, Ambiance)
# - Average ratings by time of day
# - Rating patterns across weekdays/weekends
# - Relationship between wait times and ratings
#
# b) Answer these questions:
# - Which aspect of the experience gets the highest ratings?
# - When do we tend to get our best/worst ratings?
# - How do long wait times affect different rating types?

# %% [markdown]
# ### Step 3. Customer Feedback Analysis
# a) Analyze written feedback:
# - Calculate frequency of each feedback type
# - Create a visualization of common feedback themes
# - Identify most common positive and negative feedback
#
# b) Create visualizations showing:
# - Average ratings for each type of written feedback
# - Distribution of wait times for different feedback types
# - Order value patterns for different feedback types

# %% [markdown]
# ### 4. Time Pattern Analysis (20 points)
# a) Investigate temporal patterns:
# - Create daily and weekly rating averages
# - Compare busy vs quiet periods
# - Analyze how wait times vary by time of day
# - Look for any seasonal trends
#
# b) Create a visualization showing peak times and their relationship to customer satisfaction

# %% [markdown]
# ### Step 5. Recommendations Report
# Write a brief report (250-300 words) that includes:
# - Key findings about customer satisfaction
# - Three specific recommendations for improvement
# - Suggested metrics to track

# %% [markdown]
# ## How Can We Uncover Relationships and Connections in Our Data?
#
# **Link analysis** is a data analysis technique used to evaluate relationships (often called **edges**) between different types of objects (**nodes**) in a **network.** For Juicy Lucy's Gourmet Burger Emporium, link analysis can reveal valuable insights about customer purchasing patterns, menu item associations, and even supply chain relationships.
#
# Let's walk through the link analysis process using examples from Juicy Lucy's.
#
# ### Step 1: Define the objective
#
# Clearly state the purpose of your link analysis. What relationships are you trying to uncover? What insights do you hope to gain?
#
# Example: For Juicy Lucy's, let's explore the following questions:
#
# 1.  What menu items are frequently ordered together?
# 2.  How are different ingredients connected through menu items?
# 3.  Are there distinct clusters of customers based on their ordering habits?
#
# ### Step 2: Collect and prepare the data
#
# Gather relevant data and prepare it for analysis. This often involves structuring the data into a format suitable for network analysis.
#
# Example: Let's create a sample dataset of Juicy Lucy's orders:

# %%
np.random.seed(52179)

# Define menu items and their ingredients
menu_items = {
    'Minnesotan Madness': ['Beef Patty', 'Cheese', 'Onion'],
    'Lutefisk Surprise': ['Lutefisk', 'Onion', 'Lettuce'],
    'Paul Bunyan\'s Breakfast': ['Beef Patty', 'Egg', 'Pancake Bun'],
    'Plain Jane': ['Beef Patty', 'Lettuce', 'Tomato'],
    'Veggie Delight': ['Veggie Patty', 'Lettuce', 'Tomato', 'Onion']
}

# Function to generate orders with desired characteristics
def generate_order():
    if np.random.random() < 0.3:  # 30% chance of Minnesotan Madness and Plain Jane together
        order = ['Minnesotan Madness', 'Plain Jane']
        if np.random.random() < 0.5:  # 50% chance to add another item
            remaining = list(set(menu_items.keys()) - set(order))
            order.append(np.random.choice(remaining))
    elif np.random.random() < 0.2:  # 20% chance of Veggie Delight alone
        order = ['Veggie Delight']
    else:  # Random selection for the rest
        num_items = np.random.choice([1, 2, 3], p=[0.5, 0.3, 0.2])
        item_probs = [0.3,0.3,0.2,0.1,0.1]
        order = [np.random.choice(list(menu_items.keys()), p=item_probs) for _ in range(num_items)]
        # order = list(np.random.choice(list(menu_items.keys()), num_items, replace=False))
        order = set(order)
    return order

# Generate orders
orders = [generate_order() for _ in range(1000)]

df_orders = pd.DataFrame({'Order_Items': orders})

# %% [markdown]
# This creates a DataFrame with order data and a dictionary of menu item-ingredient relationships.
#
# ### Step 3: Create the network structure
#
# Transform your data into a network structure, defining nodes and edges based on your analysis objectives.
#
# Example: Let's create a network of menu items based on co-occurrence in orders:

# %%
import networkx as nx
from itertools import combinations

# Create a graph
G = nx.Graph()

# Add edges based on co-occurrence in orders
for order in df_orders['Order_Items']:
    for item1, item2 in combinations(order, 2):
        if G.has_edge(item1, item2):
            G[item1][item2]['weight'] += 1
        else:
            G.add_edge(item1, item2, weight=1)

print(f"Number of nodes: {G.number_of_nodes()}")
print(f"Number of edges: {G.number_of_edges()}")
# Out:
# Number of nodes: 5
# Number of edges: 10

# %% [markdown]
# This creates a network where nodes are menu items, and edges represent how often items are ordered together.
#
# ### Step 4: Visualize the network
#
# Create a visual representation of your network to get an initial understanding of the relationships.
#
# Example: Let's visualize our menu item network:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G)
edges = G.edges()
weights = [G[u][v]['weight'] for u,v in edges]

nx.draw(G, pos, with_labels=True, node_color='lightblue',
        node_size=3000, font_size=10, font_weight='bold')
nx.draw_networkx_edge_labels(G, pos, edge_labels={(u,v): G[u][v]['weight'] for u,v in G.edges()})

plt.title("Menu Item Co-occurrence Network")
plt.axis('off')
plt.show()

# %% [markdown]
# This visualization helps us see which menu items are most frequently ordered together.

# %% [markdown]
# These metrics help us identify which menu items are central to the network and which ones act as bridges between different parts of the network.

# %% [markdown]
# ### Step 5: Analyze ingredient relationships
#
# Extend the analysis to ingredient-level relationships based on menu compositions.
#
# Example: Let's create and visualize an ingredient network:

# %%
# Create ingredient network
G_ingredients = nx.Graph()

# Create menu_ingredients by copying menu_items
menu_ingredients = menu_items.copy()


for item, ingredients in menu_ingredients.items():
    for ing1, ing2 in combinations(ingredients, 2):
        if G_ingredients.has_edge(ing1, ing2):
            G_ingredients[ing1][ing2]['weight'] += 1
        else:
            G_ingredients.add_edge(ing1, ing2, weight=1)

# Visualize ingredient network
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G_ingredients)
nx.draw(G_ingredients, pos, with_labels=True, node_color='lightgreen',
        node_size=3000, font_size=10, font_weight='bold')
nx.draw_networkx_edge_labels(G_ingredients, pos, edge_labels={(u,v): G_ingredients[u][v]['weight'] for u,v in G_ingredients.edges()})

plt.title("Ingredient Relationship Network")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Step 6: Calculate network metrics
#
# Compute relevant network metrics to quantify relationships and identify important nodes or connections.
#
# Example: Let's calculate some basic network metrics:

# %%
# Calculate network metrics for ingredients
degree_centrality = nx.degree_centrality(G_ingredients)
print("Ingredient Degree Centrality:")
for item, centrality in sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True):
    print(f"{item}: {centrality:.3f}")

betweenness_centrality = nx.betweenness_centrality(G_ingredients)
print("\nIngredient Betweenness Centrality:")
for item, centrality in sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True):
    print(f"{item}: {centrality:.3f}")

# %% [markdown]
# Here we see measure of **degree centrality** of a node (the **degree** of node refers to its numebers of edges/connections with other nodes), and **betweeness centrality** (how many paths through the network pass through this node). In this case, we see that "beef patty" has high degree centrality.

# %% [markdown]
# ### Step 8: Interpret results and generate insights
#
# Summarize your findings and translate them into actionable insights for the business.
#
# Example: Based on our link analysis of Juicy Lucy's data, we can conclude:
#
# 1.  Menu item relationships:
#     -   "Minnesotan Madness" and "Plain Jane" are often ordered together, suggesting they might appeal to different tastes within the same group.
#     -   "Veggie Delight" seems to have fewer strong connections, indicating it might be ordered more as a standalone item.
# 2.  Ingredient relationships:
#     -   Beef Patty, Lettuce, and Tomato form a strong cluster, reflecting their common use in multiple menu items.
#     -   Lutefisk and Pancake Bun are more peripheral, suggesting they're unique to specific menu items.
# 3.  Community detection:
#     -   The algorithm identified [X] distinct communities in our menu item network, potentially reflecting different meal types or customer preferences.
#
# Recommendations:
#
# 1.  Consider creating combo meals based on the strongest menu item relationships identified.
# 2.  Develop new menu items that combine ingredients from different clusters to create unique flavor profiles.
# 3.  Target marketing efforts towards the identified menu item communities, potentially creating themed promotions.
# 4.  Optimize inventory management based on the ingredient relationship network, ensuring that strongly connected ingredients are always stocked together.
#
# By applying these link analysis techniques, Juicy Lucy's can gain deeper insights into the relationships between their menu items and ingredients. These insights can inform menu design, inventory management, and marketing strategies to enhance customer satisfaction and operational efficiency.

# %% [markdown]
# ## In the Real World: The Far-Reaching Impact of Data Analysis
#
# Throughout this chapter, we've explored various data analysis techniques using Juicy Lucy's Gourmet Burger Emporium as our case study. However, the methods we've learned have far-reaching applications across numerous fields. Let's dive into how these techniques are applied in the real world, spanning science, business, engineering, healthcare, and beyond.
#
# ### 1. Trend Analysis in Various Fields
#
# **In Finance and Economics:**
# Financial analysts use trend analysis to predict stock market movements and economic indicators. For instance, economists at the Federal Reserve might analyze trends in unemployment rates, inflation, and GDP growth to inform monetary policy decisions. Investment firms use technical analysis, a form of trend analysis, to identify patterns in stock prices and trading volumes to make investment decisions.
#
# **In Climate Science:**
# Climate researchers employ trend analysis to study global temperature changes, sea level rise, and greenhouse gas concentrations. The Intergovernmental Panel on Climate Change (IPCC) uses long-term trend analysis of global temperature data to assess climate change impacts and inform policy recommendations.
#
# **In Public Health:**
# Epidemiologists use trend analysis to track the spread of diseases over time. During the COVID-19 pandemic, health organizations worldwide used trend analysis to monitor infection rates, hospitalizations, and vaccination progress, helping to inform public health policies and resource allocation.
#
# ### 2. Performance Analysis Across Industries
#
# **In Sports:**
# Professional sports teams use sophisticated performance analysis to evaluate players and inform strategy. For example, the use of sabermetrics in baseball, popularized by the Oakland Athletics and described in the book "Moneyball," revolutionized how teams assess player value and make recruitment decisions.
#
# **In Manufacturing:**
# Manufacturers use performance analysis to optimize production processes. Toyota's famous lean manufacturing system relies heavily on continuous performance analysis to identify inefficiencies and improve productivity. Key Performance Indicators (KPIs) like Overall Equipment Effectiveness (OEE) are used to measure and improve manufacturing performance.
#
# **In Digital Marketing:**
# Marketing teams use performance analysis to evaluate the effectiveness of their campaigns. Google Analytics, for instance, allows marketers to analyze website traffic, user behavior, and conversion rates, helping to optimize digital marketing strategies and improve ROI.
#
# ### 3. Exploratory Data Analysis in Research and Development
#
# **In Pharmaceutical Research:**
# Drug discovery often begins with exploratory data analysis of molecular databases. Researchers might use EDA techniques to identify patterns in chemical structures that correlate with certain therapeutic effects, guiding the direction of further research and drug development.
#
# **In Astrophysics:**
# The field of astrophysics generates enormous amounts of data from telescopes and satellites. Scientists use EDA to sift through this data, identifying anomalies that might indicate new celestial objects or phenomena. For example, the discovery of exoplanets often involves exploratory analysis of star brightness data to detect periodic dimming caused by orbiting planets.
#
# **In Social Sciences:**
# Sociologists and psychologists use EDA to uncover patterns in survey data or experimental results. For instance, researchers studying the impacts of social media on mental health might use EDA techniques to identify unexpected correlations or subgroups within their data, informing more targeted hypotheses for further investigation.
#
# ### 4. Link Analysis in Complex Systems
#
# **In Criminal Investigations:**
# Law enforcement agencies use link analysis to map criminal networks and understand the relationships between suspects, victims, and evidence. Tools like IBM's i2 Analyst's Notebook help investigators visualize complex criminal ecosystems, aiding in the solving of intricate cases like organized crime or terrorism networks.
#
# **In Cybersecurity:**
# Network security experts use link analysis to detect and prevent cyber attacks. By analyzing the connections between IP addresses, data packets, and user behaviors, security systems can identify potential threats and anomalies in real-time, helping to protect against data breaches and cyber threats.
#
# **In Ecology:**
# Ecologists use link analysis to study food webs and ecosystems. By mapping the relationships between different species in an ecosystem, researchers can understand the potential impacts of changes to the system, such as the introduction of an invasive species or the effects of climate change on biodiversity.
#
# ### 5. Combining Techniques in Big Data and AI
#
# **In E-commerce:**
# Companies like Amazon use a combination of trend analysis, performance analysis, and link analysis to power their recommendation systems. By analyzing purchase history trends, product performance, and the relationships between products and customers, they can provide personalized shopping experiences and targeted marketing.
#
# **In Smart Cities:**
# Urban planners and city governments are increasingly using data analysis to optimize city operations. For example, the city of Singapore uses a combination of trend analysis (to predict traffic patterns), performance analysis (to evaluate public transportation efficiency), and link analysis (to understand the relationships between different urban systems) in their "Smart Nation" initiative, aimed at improving quality of life through technology.
#
# **In Precision Agriculture:**
# Modern farming techniques incorporate various data analysis methods to optimize crop yields and resource use. Farmers use trend analysis of weather patterns and crop yields, performance analysis of different seeds and farming techniques, and link analysis to understand the relationships between soil conditions, weather, and crop health. Companies like Climate Corporation provide AI-driven recommendations to farmers based on these complex analyses.

# %% [markdown]
# ### Common Data Analytics Tools in the Industry
#
# As you progress in your data analytics journey, you'll encounter a variety of tools designed to assist in different aspects of data manipulation, analysis, and visualization. While this course has primarily focused on SQL and Python, it's important to be aware of other tools commonly used in the industry. Each tool has its strengths and is often chosen based on specific project requirements, organizational preferences, or industry standards. The following table provides an overview of some widely used data analytics tools, including open-source options, commercial software packages, and cloud-based solutions. Remember that the field of data analytics is dynamic, and new tools are constantly emerging, so it's valuable to stay informed about the evolving landscape of analytical software.
#
# | Tool | Description |
# |------|-------------|
# | Structured Query Language (SQL) | A domain-specific language used for managing and querying relational databases. SQL is essential for data extraction, transformation, and loading (ETL) processes in data analytics. |
# | Python | A versatile, high-level programming language widely used in data analysis, machine learning, and scientific computing. Python offers numerous libraries like pandas, NumPy, and scikit-learn for data manipulation and analysis. |
# | Microsoft Excel | A spreadsheet software that provides data organization, basic analysis, and visualization capabilities. While limited for large datasets, Excel is widely used for quick analyses and reporting in business environments. |
# | R | An open-source programming language and environment for statistical computing and graphics. R is particularly strong in statistical analysis and has a large ecosystem of packages for various analytical tasks. |
# | RapidMiner | A data science platform that provides an integrated environment for data prep, machine learning, and model deployment. It offers both visual workflows and coding options for analytics tasks. |
# | IBM Cognos | A business intelligence suite that provides a range of BI capabilities including reporting, analytics, scorecarding, and monitoring. It's designed for large-scale enterprise reporting and analysis. |
# | IBM SPSS Modeler | A data mining and text analytics software used to build predictive models and conduct other analytic tasks. It provides a visual interface for building analytical workflows. |
# | IBM SPSS Statistics | A software package used for statistical analysis, offering a wide range of statistical procedures and machine learning algorithms. It's commonly used in social sciences and market research. |
# | SAS | A suite of analytics software products that provides a wide range of statistical and analytical capabilities. SAS is widely used in large enterprises, particularly in industries like finance and healthcare. |
# | Tableau | A popular data visualization tool that allows users to create interactive and shareable dashboards. Tableau is known for its user-friendly interface and powerful visualization capabilities. |
# | Power BI | Microsoft's business analytics tool for visualizing data and sharing insights. It integrates well with other Microsoft products and offers both desktop and cloud-based solutions. |
# | Qlik | A business intelligence platform that offers self-service analytics and interactive dashboards. Qlik uses an associative engine to allow users to explore data relationships dynamically. |
# | MicroStrategy | An enterprise business intelligence platform that provides reporting, analytics, and mobile BI capabilities. It's designed for large-scale deployments and complex analytical requirements. |
# | BusinessObjects | SAP's set of front-end applications for business intelligence and reporting. It offers a range of tools for reporting, dashboarding, and ad-hoc analysis. |
# | Apex | A proprietary language and web-based platform for developing enterprise applications on the Salesforce platform. While primarily for app development, it's used for analytics within the Salesforce ecosystem. |
# | Dataroma | A cloud-based business intelligence platform that focuses on data visualization and dashboard creation. It offers easy-to-use tools for connecting to various data sources and creating reports. |
# | Domo | A cloud-based business intelligence platform that combines data integration, visualization, and collaboration features. It emphasizes real-time data and mobile accessibility. |
# | AWS QuickSight | Amazon's cloud-based business intelligence service that allows users to create and publish interactive dashboards. It's designed to scale automatically and integrates well with other AWS services. |
# | Stata | A general-purpose statistical software package used for data manipulation, visualization, statistics, and automated reporting. It's particularly popular in economics and biostatistics. |
# | Minitab | A statistics package developed for analyzing data in statistics courses but also used for quality improvement and data analysis in businesses. It offers both basic and advanced statistical functions. |

# %% [markdown]
# ## Review With Quizlet

# %%
# %%html
# <iframe src="https://quizlet.com/963456023/learn/embed?i=psvlh&x=1jj1" height="600" width="100%" style="border:0"></iframe>

# %% [markdown]
# ## Glossary
# | Term | Definition |
# |------|------------|
# | Analysis scope | The boundaries and limitations set for a particular analytical study, defining what will and won't be included in the investigation. |
# | Betweenness centrality | A measure of a node's importance based on how often it lies on the shortest path between other nodes in a network. |
# | Customer relationship management (CRM) system | A technology for managing all interactions and relationships with customers and potential customers, typically used to store customer data and track interactions. |
# | Data freshness | The degree to which data is up-to-date and reflects the most current state of the information it represents. |
# | Data granularity | The level of detail in a dataset; finer granularity means more detailed data, while coarser granularity indicates more aggregated data. |
# | Data lake | A centralized repository that allows storage of structured and unstructured data at any scale, typically used for big data applications. |
# | Data quality | The degree to which data is accurate, complete, consistent, and reliable for its intended use. |
# | Data warehouse | A centralized repository of integrated data from multiple sources, designed for query and analysis rather than transaction processing. |
# | Degree centrality | A measure of a node's importance in a network based on the number of direct connections it has to other nodes. |
# | Edge | A connection or relationship between two nodes in a network or graph. |
# | Exploratory Data Analysis | An approach to analyzing datasets to summarize their main characteristics, often with visual methods, to formulate hypotheses and guide further analysis. |
# | Forecast | A prediction or estimate of future events or trends based on past and present data. |
# | Gap analysis | A method of assessing the differences between current performance and desired performance to identify areas for improvement. |
# | Heatmap | A graphical representation of data where values are depicted by colors, often used to visualize complex datasets and identify patterns. |
# | Key Performance Indicators | Quantifiable measures used to evaluate the success of an organization, employee, or process in meeting objectives for performance. |
# | Link Analysis | A data analysis technique used to evaluate relationships (links) between nodes (objects, people, organizations) in a network. |
# | Moving Average | A calculation used to analyze data points by creating a series of averages of different subsets of the full dataset, often used to smooth out short-term fluctuations and highlight longer-term trends. |
# | Network | A collection of nodes (entities) and edges (relationships) that represents connections between the entities. |
# | Network diagram | A visual representation of a network, showing nodes as points and edges as lines connecting these points. |
# | Node | An entity or data point in a network, often representing a person, place, or thing. |
# | Node degree | The number of edges connected to a node in a network. |
# | Performance analysis | The process of studying and evaluating the execution and efficiency of a system, process, or individual against predetermined criteria or benchmarks. |
# | Transactional database | A database management system that is designed to handle a large number of short online transactions, typically used in operational systems. |
# | Trend analysis | A technique used in technical analysis to predict future movements based on past data, often involving the identification of patterns or trends in time series data. |
